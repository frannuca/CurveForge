# %%
from yahoo import download_timeseries
import pandas as pd

# %%
spx = download_timeseries("^SPX", start="2020-01-01", end="2023-01-01")
spx = spx.asfreq("B").ffill()

# %%
spx.plot(title="S&P 500 Index")
